# %%
import requests

# %%
import os
from dotenv import load_dotenv

load_dotenv()  # lädt Variablen aus .env
api_key = os.environ["RIOT_API_KEY"]

# %% [markdown]
# Every 24h we need to generate a new API Key from this website:
# https://developer.riotgames.com/

# %% [markdown]
# Now we move to the APIs: https://developer.riotgames.com/apis

# %% [markdown]
# 1.) Get url of a summoner: https://developer.riotgames.com/apis#account-v1/GET_getByRiotId

# %%
player_list ={"devin3000": "3000",
              "Bartonix": "tag",}

player_url = "https://europe.api.riotgames.com/riot/account/v1/accounts/by-riot-id/"

for summoner_name, tag in player_list.items():
    print(summoner_name+ ": " + player_url + summoner_name + "/" + tag +api_key)
# Out:
# devin3000: https://europe.api.riotgames.com/riot/account/v1/accounts/by-riot-id/devin3000/3000RGAPI-7e1da19b-15f8-4f75-b35e-8aca227deb33
# Bartonix: https://europe.api.riotgames.com/riot/account/v1/accounts/by-riot-id/Bartonix/tagRGAPI-7e1da19b-15f8-4f75-b35e-8aca227deb33

# %% [markdown]
# 1b) Just for one Summoner

# %%
api_url_player = "https://europe.api.riotgames.com/riot/account/v1/accounts/by-riot-id/devin3000/3000"
api_url_player = api_url_player + '?api_key=' + api_key


url_player_list= {"devin3000#3000": "europe.api.riotgames.com/riot/account/v1/accounts/by-riot-id/devin3000/3000?api_key=RGAPI-8f0b6902-d184-4e8a-b74f-c340cd710c0f",}

# %% [markdown]
# Lets get the puuid of devin3000

# %%
resp = requests.get(api_url_player)
player_info = resp.json()
player_info
# Out:
# {'puuid': 'n0hw6Jo9DQ6I1l05BtBc3n_gpVB0jrv9srAYQ2QBmSkegzeOcx_E-mOhPT4Iu61hOMh3K_mjAu8tJg',
#  'gameName': 'devin3000',
#  'tagLine': '3000'}

# %% [markdown]
# Now lets get his match history

# %%
api_url_match_history = "https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/"
start=0
count=100

# %%
match_history_api = api_url_match_history + player_info['puuid'] + "/ids?start=" + str(start) + "&count=" + str(count) + "&api_key=" + api_key
match_history=requests.get(match_history_api).json()
match_history
# Out:
# ['EUW1_7706438373',
#  'EUW1_7706393118',
#  'EUW1_7705060525',
#  'EUW1_7705029296',
#  'EUW1_7704998267',
#  'EUW1_7704948235',
#  'EUW1_7704892087',
#  'EUW1_7704844899',
#  'EUW1_7704785896',
#  'EUW1_7704404792',
#  'EUW1_7703634749',
#  'EUW1_7703595079',
#  'EUW1_7703560511',
#  'EUW1_7702998405',
#  'EUW1_7702897917',
#  'EUW1_7700617106',
#  'EUW1_7700595356',
#  'EUW1_7700567339',
#  'EUW1_7700531761',
#  'EUW1_7700473483',
#  'EUW1_7700398738',
#  'EUW1_7696033795',
#  'EUW1_7696009814',
#  'EUW1_7695953367',
#  'EUW1_7695849648',
#  'EUW1_7695399926',
#  'EUW1_7695277207',
#  'EUW1_7694581339',
#  'EUW1_7694543431',
#  'EUW1_7694492346',
#  'EUW1_7691799837',
#  'EUW1_7691755018',
#  'EUW1_7691674316',
#  'EUW1_7691594572',
#  'EUW1_7691494981',
#  'EUW1_7690276024',
#  'EUW1_7690242652',
#  'EUW1_7690205605',
#  'EUW1_7690160172',
#  'EUW1_7690116032',
#  'EUW1_7689610853',
#  'EUW1_7687950154',
#  'EUW1_7687871727',
#  'EUW1_7687803247',
#  'EUW1_7687232844',
# ...

# %% [markdown]
# Lets do a deepdive into one of his games

# %%
api_url_game = "https://europe.api.riotgames.com/lol/match/v5/matches/"
game_id = "EUW1_7706438373"
api_url_game = api_url_game + game_id +'?api_key=' + api_key
resp = requests.get(api_url_game)
match_data = resp.json()
match_data
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File c:\Users\devin\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...

# %% [markdown]
# Lets Calculate the KDA of a player

# %%
player_data=match_data["info"]["participants"][0]
k = player_data["kills"]
d = player_data["deaths"]
a = player_data["assists"]
kda = (k+a)/d

print("Kills:",k)
print("Deaths:", d)
print("Assists:",a)
print("KDA:", kda)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 player_data=match_data["info"]["participants"][0]
#       2 k = player_data["kills"]
#       3 d = player_data["deaths"]
#
# KeyError: 'info'

# %%
#list of all the participant puuids
participants = match_data['metadata']['participants']
print("Participants:", participants)
#now find our puuid int his case from devin3000
player_index = participants.index(puuid)
print("Player_index:", player_index)
# Out:
# Participants: ['VticYfhJQ8RgEXay2rzqmxSLmn8_pfs18iZamD9weew0iZELULQMktOzaJ4mmbP_jupTYUw5EW7yPQ', 'dLXWGJUMImqEAmnCirZvC3gLe5tnaWFDBsMozVLV8x_D3XeinyP4eJtJ1NjEUtVfLoGdIBoH0ZmLUA', 'ZHuPvyttWqw9dJVCHlTLnluys9Qnmw7uY3HC-8sNMK0WqJ_Ai5nPS-qbVsmUGk1VVNW9YJgH9Y_FDQ', 'yaOXTIzQ8fuwbkeu4VI7BruunV5vieBbk_f4lmptFhJVTbc8iHqu62TDn_KhuB9PKxoEQG_UxLLEiw', 'aaM4n4b4tDXJ85pM8ZYIFiXmvN34WKJ_T1oTOUZtkioxk3ykbqZ66ZT3hRer_VesHhgF4z_q7sqfsQ', 'Jr0LcWJP_3VWj5VBIOSvLeUVSOdzlyNdE-GVxyomE8XloTEsSfNvMI1TxVzE__AlYI7XBJJNC_aBqw', '5cIO4Dtq8DgTz2X98A5e7je4nhMRGuNLS3Tln29d0jdhR-y-El_YyhSeJdDhVYPS-xGbTywYuoGhyw', 'IdW9XP2vRYO10dQGsVZTdT-piMUP83qAs7sdhTKAoYYQ3ZiXYlGBUElnsnilV-fL4fxb9Lv_NkF8fQ', 'n0hw6Jo9DQ6I1l05BtBc3n_gpVB0jrv9srAYQ2QBmSkegzeOcx_E-mOhPT4Iu61hOMh3K_mjAu8tJg', 'cQmNxCFEahDKj5L2AGzlHyBGPeV96nRMAOHShYhfgTnxkeDe4ZcN8PPCVaeXyqd4ua250Ez6LdiHaA']
# Player_index: 8

# %%
match_data['info']['participants'][player_index]
# Out:
# {'PlayerScore0': 0,
#  'PlayerScore1': 0,
#  'PlayerScore10': 0,
#  'PlayerScore11': 0,
#  'PlayerScore2': 0,
#  'PlayerScore3': 0,
#  'PlayerScore4': 0,
#  'PlayerScore5': 0,
#  'PlayerScore6': 0,
#  'PlayerScore7': 0,
#  'PlayerScore8': 0,
#  'PlayerScore9': 0,
#  'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 12,
#  'baronKills': 1,
#  'basicPings': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'HealFromMapSources': 152,
#   'InfernalScalePickup': 0,
#   'SWARM_DefeatAatrox': 0,
#   'SWARM_DefeatBriar': 0,
#   'SWARM_DefeatMiniBosses': 0,
#   'SWARM_EvolveWeapon': 0,
#   'SWARM_Have3Passives': 0,
#   'SWARM_KillEnemy': 0,
#   'SWARM_PickupGold': 0,
#   'SWARM_ReachLevel50': 0,
#   'SWARM_Survive15Min': 0,
#   'SWARM_WinWith5EvolvedWeapons': 0,
#   'abilityUses': 203,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 1,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 648.3198852539062,
#   'buffsStolen': 0,
# ...
